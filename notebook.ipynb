# %% [markdown]
# Note that this notebook was automatically generated from an RDocumentation page. It depends on the package and the example code whether this code will run without errors. You may need to edit the code to make things work.

# %%
if(!require('graphics')) {
    install.packages('graphics')
    library('graphics')
}

# %%
library(ggplot2)

bank_counts_df <- data.frame(Bank_Code = c("0010", "0003", "0004"), Bank_Count = c(25, 30, 22))
# Displaying the dataframe
print(bank_counts_df)


# Define the conditions and replacement values
bank_codes <- c("0010", "0003", "0004")
bank_names <- c("CIBC", "TD", "RBC")
 
# Use replace() to replace the names in the 'Names' column
bank_counts_df$Bank_Code <- replace(bank_counts_df$Bank_Code, bank_counts_df$Bank_Code %in% bank_codes, bank_names)



# bank_counts_df$Bank_Code <- replace(bank_counts_df$Bank_Code, bank_counts_df$Bank_Code = 0010, "CIBC")
# bank_counts_df$Bank_Code["0010"] <- "CIBC"
print(bank_counts_df)


# Easier than ggplot() + geom_bar
barplot(height=bank_counts_df$Bank_Count, names=bank_counts_df$Bank_Code, density=c(5,10,20) , angle=c(0,45,90) , col="blue")





# ggplot(Bank_counts_df, aes(x=Bank_Code, y=Bank_Count)) + geom_bar(stat = "identity", width=0.5) +  scale_fill_hue(c = 40) + theme(legend.position="none")

#  scale_fill_manual(values = c("red", "green", "blue") ) +
#  theme(legend.position="none")
# Out:
#   Bank_Code Bank_Count
# 1      0010         25
# 2      0003         30
# 3      0004         22
#   Bank_Code Bank_Count
# 1      CIBC         25
# 2        TD         30
# 3       RBC         22
# plot without title
